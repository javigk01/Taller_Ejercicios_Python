# %% [markdown]
# ![](https://logoeps.com/wp-content/uploads/2013/04/pontificia-universidad-javeriana-vector-logo.png)
# # PONTIFICIA UNIVERSIDAD JAVERIANA
#
# ### Procesamiento de Alto Volumen de Datos
#
# **Fecha:** Por definir (ver fecha acordada en clase)
#
# **Autor:** John Corredor Franco
#
# **Estudiante:** Javier Felipe Aldana Jaramillo
#
# **Tema:** Bucles
#
# **Objetivos:**
#
# - Comprender el funcionamiento de los bucles for y while.
# - Practicar el uso de control de flujo (break, continue, else en bucles).
# - Resolver ejercicios practicos que impliquen iteracion.
# - Documentar el proceso de solucion de cada ejercicio.
# - Elaborar conclusiones sobre la eficiencia y el uso adecuado de los bucles.

# %% [markdown]
# ## Actividades / Ejercicios

# %% [markdown]
# ### Ejercicio 1
#
# **Instruccion:** _(pegar aqui el enunciado del ejercicio 1 de Bucles tal como aparece en el taller)_
#
# **Descripcion personal:** _(explica brevemente, con tus palabras, que pide el ejercicio y como piensas resolverlo)_

# %%
# Solucion ejercicio 1

# %% [markdown]
# **Explicacion del algoritmo/resultado:** _(describe brevemente que hace tu codigo y por que funciona)_

# %% [markdown]
# ### Ejercicio 2
#
# **Instruccion:** _(pegar aqui el enunciado del ejercicio 2 de Bucles tal como aparece en el taller)_
#
# **Descripcion personal:** _(explica brevemente, con tus palabras, que pide el ejercicio y como piensas resolverlo)_

# %%
# Solucion ejercicio 2

# %% [markdown]
# **Explicacion del algoritmo/resultado:** _(describe brevemente que hace tu codigo y por que funciona)_

# %% [markdown]
# ### Ejercicio 3
#
# **Instruccion:** _(pegar aqui el enunciado del ejercicio 3 de Bucles tal como aparece en el taller)_
#
# **Descripcion personal:** _(explica brevemente, con tus palabras, que pide el ejercicio y como piensas resolverlo)_

# %%
# Solucion ejercicio 3

# %% [markdown]
# **Explicacion del algoritmo/resultado:** _(describe brevemente que hace tu codigo y por que funciona)_

# %% [markdown]
# ## Conclusiones
#
# _(conclusiones personales sobre lo aprendido en este cuaderno)_
