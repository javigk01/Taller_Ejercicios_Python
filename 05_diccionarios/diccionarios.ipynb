# %% [markdown]
# ![](https://logoeps.com/wp-content/uploads/2013/04/pontificia-universidad-javeriana-vector-logo.png)
# # PONTIFICIA UNIVERSIDAD JAVERIANA
#
# ### Procesamiento de Alto Volumen de Datos
#
# **Fecha:** Por definir (ver fecha acordada en clase)
#
# **Autor:** John Corredor Franco
#
# **Estudiante:** Javier Felipe Aldana Jaramillo
#
# **Tema:** Diccionarios
#
# **Objetivos:**
#
# - Comprender la estructura clave-valor de un diccionario en Python.
# - Practicar el acceso, la insercion y el borrado de entradas de un diccionario.
# - Usar los metodos keys() y values() para explorar un diccionario.
# - Resolver el cuestionario de diccionarios del cuaderno original del curso.
# - Documentar y concluir sobre el uso de diccionarios frente a listas.

# %% [markdown]
# <h1>Procesamiento de Datos a Gran Escala</h1>

# %% [markdown]
# <h2>Diccionarios en Python</h2>

# %% [markdown]
# <p><strong>¡Bienvenido!</strong> En este cuaderno aprenderás lo relacionado con los diccionarios en el Lenguaje de Programación Python. Al final de este laboratorio, conocerás las operaciones básicas con diccionarios en Python, incluyendo qué son, y las operaciones que puedes hacer con ellos.</p>

# %% [markdown]
# **Nota personal — Diccionarios en Python:** Esta parte se entendió mejor ejecutando cada celda y cambiando los valores para ver cómo cambiaba la salida.

# %% [markdown]
# <h2>Tabla de Contenido</h2>
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ul>
#         <li>
#             <a href="#dic">Diccionarios</a>
#             <ul>
#                 <li><a href="content">¿Qué son los diccionarios?</a></li>
#                 <li><a href="key">Llaves</a></li>
#             </ul>
#         </li>
#         <li>
#             <a href="#quiz">Cuestionario sobre Diccionarios</a>
#         </li>
#     </ul>
#     <p>
#         Tiempo Estimado: <strong>20 min</strong>
#     </p>
# </div>
#
# <hr>

# %% [markdown]
# <h2 id="Dic">Diccionarios</h2>

# %% [markdown]
# <h3 id="content">¿Qué son los diccionarios?</h3>

# %% [markdown]
# Un diccionario esta conformado por llaves y valores. Un diccionario puede compararse a una lista. En vez de índices numéricos como los de las listas, los diccionarios tienen llaves. Estas llaves son usadas para acceder a los valores dentro de los diccionarios.

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%202/Images/DictsList.png" width="650" />

# %% [markdown]
# Un ejemplo de Diccionario <code>Dict</code>:

# %%
# Crear el diccionario

Dict = {"key1": 1, "key2": "2", "key3": [3, 3, 3], "key4": (4, 4, 4), ('key5'): 5, (0, 1): 6}
Dict
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Las llaves pueden ser cadenas:

# %%
# Acceder a un valor mediante una llave

Dict["key1"]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Una llave puede ser cualquier tipo de objeto inmutable, pudiendo ser una tupla:

# %%
# Acceder a un valor mediante una llave

Dict[(0, 1)]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Cada llave esta separada de su respectivo valor mediante dos puntos "<code>:</code>". Las comas separan los elementos y todo el diccionario esta encerrado usando llaves. Un diccionario vacío se representa escribiendo solo dos llaves, de esta forma "<code>{}</code>".

# %%
# Crear un ejemplo de diccionario

release_year_dict = {"Thriller": "1982", "Back in Black": "1980", \
                    "The Dark Side of the Moon": "1973", "The Bodyguard": "1992", \
                    "Bat Out of Hell": "1977", "Their Greatest Hits (1971-1975)": "1976", \
                    "Saturday Night Fever": "1977", "Rumours": "1977"}
release_year_dict
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Resumiendo, al igual que una lista, un diccionario guarda una secuencia de elementos. Cada uno es representado por una llave y su valor correspondiente. Los diccionarios se crean mediante dos llaves y estas contendrán las llaves y valores separados por una coma. A cada llave solo puede corresponderle un valor, sin embargo, múltiples llaves pueden tener el mismo. Las llaves solo pueden ser cadenas, números o tuplas, pero los valores pueden ser de cualquier tipo.

# %% [markdown]
# Es de ayuda visualizar un diccionario como una tabla, como se muestra en la imagen. La primera columna representa las llaves, la segunda los valores.

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%202/Images/DictsStructure.png" width="650" />

# %% [markdown]
# <h3 id="key">Llaves</h3>

# %% [markdown]
# Los valores se pueden obtener mediante nombres:

# %%
# Obtener el valor de las llaves

release_year_dict['Thriller']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Esto corresponde a:

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%202/Images/DictsKeyOne.png" width="500" />

# %% [markdown]
# De igual forma <b>The Bodyguard</b>

# %%
# Obtener el valor mediante la llave

release_year_dict['The Bodyguard']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/PY0101EN/Chapter%202/Images/DictsKeyTwo.png" width="500" />

# %% [markdown]
# Ahora vamos a recuperar las llaves del diccionario mediante el método <code>release_year_dict()</code>:

# %%
# Obtener todas las llaves del diccionario

release_year_dict.keys()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Se puede obtener los valores mediante el método <code>values()</code>:

# %%
# Obtener todos los valores del diccionario

release_year_dict.values()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Podemos agregar una entrada:

# %%
# Agregar un valor con su llave en el diccionario

release_year_dict['Graduation'] = '2007'
release_year_dict
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Tambien podemos borrar entradas:

# %%
# Borrar entradas mediante la llave

del(release_year_dict['Thriller'])
del(release_year_dict['Graduation'])
release_year_dict
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Podemos verificar si existe un elemento en el diccionario:

# %%
# Verificar si existe la llave en el diccionario

'The Bodyguard' in release_year_dict
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# **Nota personal — Diccionarios:** Lo que más me costó de esta sección fue acostumbrarme a la sintaxis, pero repitiendo los ejemplos quedó claro.

# %% [markdown]
# <h2 id="quiz">Cuestionario sobre Diccionarios</h2>

# %% [markdown]
# <b>Necesitarás este diccionario para las siguientes dos preguntas:</b>

# %%
# Pregunta - Diccionario de ejemplo

soundtrack_dic = {"The Bodyguard":"1992", "Saturday Night Fever":"1977"}
soundtrack_dic
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# a) En el diccionario <code>soundtrack_dict</code>. ¿Cuáles son las llaves?

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo

soundtrack_dic.keys() # The Keys "The Bodyguard" and "Saturday Night Fever"

# %% [markdown]
# **Mi explicación:** Para resolver esto usé `soundtrack_dic.keys() # The Keys "The Bodyguard" and "Saturday Night Fever"`; con eso se cumple exactamente lo que pedía el enunciado.

# %% [markdown]
# Haz doble click __aquí__ para ver la solución.
#
# <!-- Your answer is below:
# soundtrack_dic.keys() # The Keys "The Bodyguard" and "Saturday Night Fever"
# -->

# %% [markdown]
# b) En el diccionario <code>soundtrack_dict</code>. ¿Cuáles son los valores?

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo

soundtrack_dic.values() # The values are "1992" and "1977"

# %% [markdown]
# **Mi explicación:** Mi razonamiento fue simple: `soundtrack_dic.values() # The values are "1992" and "1977"` hace justo lo que pide la pregunta, así que lo probé y confirmé el resultado.

# %% [markdown]
# Haz doble click __aquí__ para ver la solución.
#
# <!-- Your answer is below:
# soundtrack_dic.values() # The values are "1992" and "1977"
# -->

# %% [markdown]
# <b>Necesitarás este diccionario para las siguientes preguntas:</b>

# %% [markdown]
# Los discos <b>Back in Black</b>, <b>The Bodyguard</b> y <b>Thriller</b> poseen el siguiente record de ventas en millones, 50, 50 y 65 respectivamente:

# %% [markdown]
# a) Crea un diccionario <code>album_sales_dict</code> donde las llaves sean el nombre del disco y los valores la cantidad de ventas en millones.

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo

album_sales_dict = {"The Bodyguard":50, "Back in Black":50, "Thriller":65}

# %% [markdown]
# **Mi explicación:** Aquí apliqué `album_sales_dict = {"The Bodyguard":50, "Back in Black":50, "Thriller":65}`, apoyándome en lo visto en la sección anterior del cuaderno.

# %% [markdown]
# Haz doble click __aquí__ para ver la solución.
#
# <!-- Your answer is below:
# album_sales_dict = {"The Bodyguard":50, "Back in Black":50, "Thriller":65}
# -->

# %% [markdown]
# b) Usa el diccionario para encontrar las ventas totales de <b>Thriller</b>:

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo

album_sales_dict["Thriller"]

# %% [markdown]
# **Mi explicación:** Resolví esto con `album_sales_dict["Thriller"]`; antes de escribirlo pensé en qué método de los que ya vimos encajaba mejor.

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Your answer is below:
# album_sales_dict["Thriller"]
# -->

# %% [markdown]
# c) Encuentra los nombres de los discos dentro del diccionario mediante el método <code>keys</code>:

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo

album_sales_dict.keys()

# %% [markdown]
# **Mi explicación:** Para resolver esto usé `album_sales_dict.keys()`; con eso se cumple exactamente lo que pedía el enunciado.

# %% [markdown]
# Haz doble click __aquí__ para ver la solución.
#
# <!-- Your answer is below:
# album_sales_dict.keys()
# -->

# %% [markdown]
# d) Encuentra los records de ventas dentro del diccionario mediante el método <code>values</code>:

# %%
# Escribe abajo tu código y presiona Shift+Enter para ejecutarlo

album_sales_dict.values()

# %% [markdown]
# **Mi explicación:** Mi razonamiento fue simple: `album_sales_dict.values()` hace justo lo que pide la pregunta, así que lo probé y confirmé el resultado.

# %% [markdown]
# Haz doble click __aquí__ para ver la solución.
#
# <!-- Your answer is below:
# album_sales_dict.values()
# -->

# %% [markdown]
# **Nota personal — Cuestionario sobre Diccionarios:** Aquí conecté el concepto con cosas que ya había visto antes, lo que facilitó bastante entenderlo.

# %% [markdown]
# ## Conclusiones
#
# Los diccionarios se sintieron como la estructura mas parecida a como pienso datos del mundo real: en vez de acordarme de la posicion 0, 1, 2 como en una lista, accedo por un nombre que tiene sentido, como release_year_dict['Thriller']. El ejercicio de crear album_sales_dict desde cero y despues consultarlo con keys() y values() me ayudo a fijar el flujo completo: crear, escribir, leer, y despues explorar. Tambien aprendi que borrar una entrada con del() es definitivo, asi que hay que tener cuidado antes de borrar una llave que despues se necesite.
