# %% [markdown]
# ![](https://logoeps.com/wp-content/uploads/2013/04/pontificia-universidad-javeriana-vector-logo.png)
# # PONTIFICIA UNIVERSIDAD JAVERIANA
#
# ### Procesamiento de Alto Volumen de Datos
#
# **Fecha:** Por definir (ver fecha acordada en clase)
#
# **Autor:** John Corredor Franco
#
# **Estudiante:** Javier Felipe Aldana Jaramillo
#
# **Tema:** Bono - Ejercicio Integrador
#
# **Objetivos:**
#
# - Integrar varias estructuras de datos y conceptos vistos en el taller en un solo ejercicio.
# - Resolver un reto adicional que combine cadenas, listas, diccionarios, condicionales, bucles, funciones y/o clases.
# - Documentar el proceso de solucion de forma detallada.
# - Elaborar conclusiones generales sobre el aprendizaje del taller completo.

# %% [markdown]
# ## Actividades / Ejercicios

# %% [markdown]
# ### Ejercicio 1
#
# **Instruccion:** _(pegar aqui el enunciado del ejercicio 1 de Bono - Ejercicio Integrador tal como aparece en el taller)_
#
# **Descripcion personal:** _(explica brevemente, con tus palabras, que pide el ejercicio y como piensas resolverlo)_

# %%
# Solucion ejercicio 1

# %% [markdown]
# **Explicacion del algoritmo/resultado:** _(describe brevemente que hace tu codigo y por que funciona)_

# %% [markdown]
# ### Ejercicio 2
#
# **Instruccion:** _(pegar aqui el enunciado del ejercicio 2 de Bono - Ejercicio Integrador tal como aparece en el taller)_
#
# **Descripcion personal:** _(explica brevemente, con tus palabras, que pide el ejercicio y como piensas resolverlo)_

# %%
# Solucion ejercicio 2

# %% [markdown]
# **Explicacion del algoritmo/resultado:** _(describe brevemente que hace tu codigo y por que funciona)_

# %% [markdown]
# ### Ejercicio 3
#
# **Instruccion:** _(pegar aqui el enunciado del ejercicio 3 de Bono - Ejercicio Integrador tal como aparece en el taller)_
#
# **Descripcion personal:** _(explica brevemente, con tus palabras, que pide el ejercicio y como piensas resolverlo)_

# %%
# Solucion ejercicio 3

# %% [markdown]
# **Explicacion del algoritmo/resultado:** _(describe brevemente que hace tu codigo y por que funciona)_

# %% [markdown]
# ## Conclusiones
#
# _(conclusiones personales sobre lo aprendido en este cuaderno)_
