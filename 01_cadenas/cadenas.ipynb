# %% [markdown]
# ![](https://logoeps.com/wp-content/uploads/2013/04/pontificia-universidad-javeriana-vector-logo.png)
# # PONTIFICIA UNIVERSIDAD JAVERIANA
#
# ### Procesamiento de Alto Volumen de Datos
#
# **Fecha:** Por definir (ver fecha acordada en clase)
#
# **Autor:** John Corredor Franco
#
# **Estudiante:** Javier Felipe Aldana Jaramillo
#
# **Tema:** Cadenas (Strings)
#
# **Objetivos:**
#
# - Comprender la creacion, indexacion y slicing de cadenas de texto en Python.
# - Aplicar metodos nativos de strings (formateo, busqueda, reemplazo, split/join).
# - Practicar la manipulacion de texto mediante ejercicios guiados.
# - Documentar el razonamiento detras de cada solucion.
# - Elaborar conclusiones sobre el manejo de cadenas en Python.

# %% [markdown]
# ## Actividades / Ejercicios

# %% [markdown]
# ### Ejercicio 1
#
# **Instruccion:** _(pegar aqui el enunciado del ejercicio 1 de Cadenas (Strings) tal como aparece en el taller)_
#
# **Descripcion personal:** _(explica brevemente, con tus palabras, que pide el ejercicio y como piensas resolverlo)_

# %%
# Solucion ejercicio 1

# %% [markdown]
# **Explicacion del algoritmo/resultado:** _(describe brevemente que hace tu codigo y por que funciona)_

# %% [markdown]
# ### Ejercicio 2
#
# **Instruccion:** _(pegar aqui el enunciado del ejercicio 2 de Cadenas (Strings) tal como aparece en el taller)_
#
# **Descripcion personal:** _(explica brevemente, con tus palabras, que pide el ejercicio y como piensas resolverlo)_

# %%
# Solucion ejercicio 2

# %% [markdown]
# **Explicacion del algoritmo/resultado:** _(describe brevemente que hace tu codigo y por que funciona)_

# %% [markdown]
# ### Ejercicio 3
#
# **Instruccion:** _(pegar aqui el enunciado del ejercicio 3 de Cadenas (Strings) tal como aparece en el taller)_
#
# **Descripcion personal:** _(explica brevemente, con tus palabras, que pide el ejercicio y como piensas resolverlo)_

# %%
# Solucion ejercicio 3

# %% [markdown]
# **Explicacion del algoritmo/resultado:** _(describe brevemente que hace tu codigo y por que funciona)_

# %% [markdown]
# ## Conclusiones
#
# _(conclusiones personales sobre lo aprendido en este cuaderno)_
