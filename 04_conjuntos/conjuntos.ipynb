# %% [markdown]
# ![](https://logoeps.com/wp-content/uploads/2013/04/pontificia-universidad-javeriana-vector-logo.png)
# # PONTIFICIA UNIVERSIDAD JAVERIANA
#
# ### Procesamiento de Alto Volumen de Datos
#
# **Fecha:** Por definir (ver fecha acordada en clase)
#
# **Autor:** John Corredor Franco
#
# **Estudiante:** Javier Felipe Aldana Jaramillo
#
# **Tema:** Conjuntos (Sets)
#
# **Objetivos:**
#
# - Comprender el concepto de conjunto (set) y sus propiedades (no duplicados, sin orden).
# - Aplicar operaciones de conjuntos (union, interseccion, diferencia, diferencia simetrica).
# - Resolver ejercicios practicos utilizando conjuntos.
# - Documentar el razonamiento de cada solucion.
# - Elaborar conclusiones sobre cuando usar conjuntos frente a otras estructuras.

# %% [markdown]
# ## Actividades / Ejercicios

# %% [markdown]
# ### Ejercicio 1
#
# **Instruccion:** _(pegar aqui el enunciado del ejercicio 1 de Conjuntos (Sets) tal como aparece en el taller)_
#
# **Descripcion personal:** _(explica brevemente, con tus palabras, que pide el ejercicio y como piensas resolverlo)_

# %%
# Solucion ejercicio 1

# %% [markdown]
# **Explicacion del algoritmo/resultado:** _(describe brevemente que hace tu codigo y por que funciona)_

# %% [markdown]
# ### Ejercicio 2
#
# **Instruccion:** _(pegar aqui el enunciado del ejercicio 2 de Conjuntos (Sets) tal como aparece en el taller)_
#
# **Descripcion personal:** _(explica brevemente, con tus palabras, que pide el ejercicio y como piensas resolverlo)_

# %%
# Solucion ejercicio 2

# %% [markdown]
# **Explicacion del algoritmo/resultado:** _(describe brevemente que hace tu codigo y por que funciona)_

# %% [markdown]
# ### Ejercicio 3
#
# **Instruccion:** _(pegar aqui el enunciado del ejercicio 3 de Conjuntos (Sets) tal como aparece en el taller)_
#
# **Descripcion personal:** _(explica brevemente, con tus palabras, que pide el ejercicio y como piensas resolverlo)_

# %%
# Solucion ejercicio 3

# %% [markdown]
# **Explicacion del algoritmo/resultado:** _(describe brevemente que hace tu codigo y por que funciona)_

# %% [markdown]
# ## Conclusiones
#
# _(conclusiones personales sobre lo aprendido en este cuaderno)_
