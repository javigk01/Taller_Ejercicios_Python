# %% [markdown]
# ![](https://logoeps.com/wp-content/uploads/2013/04/pontificia-universidad-javeriana-vector-logo.png)
# # PONTIFICIA UNIVERSIDAD JAVERIANA
#
# ### Procesamiento de Alto Volumen de Datos
#
# **Fecha:** Por definir (ver fecha acordada en clase)
#
# **Autor:** John Corredor Franco
#
# **Estudiante:** Javier Felipe Aldana Jaramillo
#
# **Tema:** Tuplas
#
# **Objetivos:**
#
# - Entender la inmutabilidad y el uso de tuplas como estructura de datos.
# - Practicar el empaquetado y desempaquetado (packing/unpacking) de tuplas.
# - Comparar tuplas con listas para identificar casos de uso apropiados.
# - Resolver ejercicios practicos con tuplas.
# - Documentar conclusiones sobre ventajas y limitaciones de las tuplas.

# %% [markdown]
# ## Actividades / Ejercicios

# %% [markdown]
# ### Ejercicio 1
#
# **Instruccion:** _(pegar aqui el enunciado del ejercicio 1 de Tuplas tal como aparece en el taller)_
#
# **Descripcion personal:** _(explica brevemente, con tus palabras, que pide el ejercicio y como piensas resolverlo)_

# %%
# Solucion ejercicio 1

# %% [markdown]
# **Explicacion del algoritmo/resultado:** _(describe brevemente que hace tu codigo y por que funciona)_

# %% [markdown]
# ### Ejercicio 2
#
# **Instruccion:** _(pegar aqui el enunciado del ejercicio 2 de Tuplas tal como aparece en el taller)_
#
# **Descripcion personal:** _(explica brevemente, con tus palabras, que pide el ejercicio y como piensas resolverlo)_

# %%
# Solucion ejercicio 2

# %% [markdown]
# **Explicacion del algoritmo/resultado:** _(describe brevemente que hace tu codigo y por que funciona)_

# %% [markdown]
# ### Ejercicio 3
#
# **Instruccion:** _(pegar aqui el enunciado del ejercicio 3 de Tuplas tal como aparece en el taller)_
#
# **Descripcion personal:** _(explica brevemente, con tus palabras, que pide el ejercicio y como piensas resolverlo)_

# %%
# Solucion ejercicio 3

# %% [markdown]
# **Explicacion del algoritmo/resultado:** _(describe brevemente que hace tu codigo y por que funciona)_

# %% [markdown]
# ## Conclusiones
#
# _(conclusiones personales sobre lo aprendido en este cuaderno)_
